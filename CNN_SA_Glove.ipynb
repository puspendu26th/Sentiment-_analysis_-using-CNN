# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer

from keras.initializers import Constant
from keras.models import Model
from keras.layers import *
from keras.utils.np_utils import to_categorical
import re
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pathlib
df=pd.read_csv('/content/drive/MyDrive/archive (6)/all-data.csv')
df
# Out:
#      Sentiment                                          text_line
# 0      neutral  According to Gran , the company has no plans t...
# 1      neutral  Technopolis plans to develop in stages an area...
# 2     negative  The international electronic industry company ...
# 3     positive  With the new production plant the company woul...
# 4     positive  According to the company 's updated strategy f...
# ...        ...                                                ...
# 4841  negative  LONDON MarketWatch -- Share prices ended lower...
# 4842   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4843  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844  negative  Net sales of the Paper segment decreased to EU...
# 4845  negative  Sales in Finland decreased by 10.5 % in Januar...
#
# [4846 rows x 2 columns]

# %%
def clean_str(in_str):
    in_str = str(in_str)
    # replace urls with 'url'
    in_str = re.sub(r"(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9]\.[^\s]{2,})", "url", in_str)
    in_str = re.sub(r'([^\s\w]|_)+', '', in_str)
    return in_str.strip().lower()


df['text'] = df['text_line'].apply(clean_str)

# %%
df.Sentiment.value_counts()
# Out:
# neutral     2879
# positive    1363
# negative     604
# Name: Sentiment, dtype: int64

# %%
df_0 = df[df['Sentiment'] == 'positive'].sample(frac=1)
df_1 = df[df['Sentiment'] == 'negative'].sample(frac=1)
df_2 = df[df['Sentiment'] == 'neutral'].sample(frac=1)
sample_size = 604

data = pd.concat([df_0.head(sample_size), df_1.head(sample_size), df_2.head(sample_size)]).sample(frac=1)

# %%
from keras.utils import pad_sequences
from tensorflow.python.keras import regularizers

# %%
data['l'] = data['text'].apply(lambda x: len(str(x).split(' ')))
print("mean length of sentence: " + str(data.l.mean()))
print("max length of sentence: " + str(data.l.max()))
print("std dev length of sentence: " + str(data.l.std()))
# Out:
# mean length of sentence: 22.4939293598234
# max length of sentence: 55
# std dev length of sentence: 9.968889575682285

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data['text'])
num_unique_tokens = len(tokenizer.word_index)
print(num_unique_tokens)
# Out:
# 6167

# %%
max_features = num_unique_tokens+1
tokenizer = Tokenizer(num_words=max_features, split=' ', oov_token='<unw>')
tokenizer.fit_on_texts(data['text'].values)

# %%
import json
word_index = tokenizer.word_index

word_to_index = tokenizer.word_index
file_path = 'w2i1.json'
with open(file_path, 'w') as json_file:
    json.dump(word_to_index, json_file)

# %%
sequence_length=55
num_filters=100
embedding_dim=200

# %%
inputs = Input(shape=(sequence_length,), dtype='int32')


embedding_layer = Embedding(input_dim=max_features, output_dim=embedding_dim, input_length=sequence_length)(inputs)

reshape = Reshape((sequence_length, embedding_dim, 1))(embedding_layer)


conv_0 = Conv2D(num_filters, kernel_size=(3, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape)
conv_1 = Conv2D(num_filters, kernel_size=(4, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape)
conv_2 = Conv2D(num_filters, kernel_size=(5, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape)
maxpool_0 = MaxPool2D(pool_size=(sequence_length - 3 + 1, 1), strides=(1,1), padding='valid')(conv_0)
maxpool_1 = MaxPool2D(pool_size=(sequence_length - 4 + 1, 1), strides=(1,1), padding='valid')(conv_1)
maxpool_2 = MaxPool2D(pool_size=(sequence_length - 5 + 1, 1), strides=(1,1), padding='valid')(conv_2)

# concat and flatten
concatenated_tensor = Concatenate(axis=1)([maxpool_0, maxpool_1, maxpool_2])
flatten = Flatten()(concatenated_tensor)

# do dropout and predict
dropout = Dropout(0.5)(flatten)
output = Dense(units=3, activation='softmax')(dropout)

# %%
temp_model = tf.keras.Model(inputs=inputs, outputs=embedding_layer)
embedding_weights = temp_model.get_weights()[0]
embedding_matrix_file = 'matrics1.npy'
np.save(embedding_matrix_file, embedding_weights)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
ck=ModelCheckpoint("model3.h5",monitor="val_accuracy",save_best_only=True,verbose=1)

# %%
model = Model(inputs=inputs, outputs=output)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 55)]         0           []
#
#  embedding (Embedding)          (None, 55, 200)      1233600     ['input_1[0][0]']
#
#  reshape (Reshape)              (None, 55, 200, 1)   0           ['embedding[0][0]']
#
#  conv2d (Conv2D)                (None, 53, 1, 100)   60100       ['reshape[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 52, 1, 100)   80100       ['reshape[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 51, 1, 100)   100100      ['reshape[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 1, 1, 100)    0           ['conv2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3, 1, 100)    0           ['max_pooling2d[0][0]',
#                                                                   'max_pooling2d_1[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  flatten (Flatten)              (None, 300)          0           ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 300)          0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 3)            903         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,474,803
# Trainable params: 1,474,803
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
X = tokenizer.texts_to_sequences(data['text'].values)


X = pad_sequences(X, sequence_length,padding='post')

y = pd.get_dummies(data['Sentiment']).values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
batch_size =50
history = model.fit(X, y, epochs=100, batch_size=batch_size, verbose=1, validation_data=(X_test,y_test), shuffle=True, callbacks=[ck])
# Out:
# Epoch 1/100
# 37/37 [==============================] - ETA: 0s - loss: 3.0455 - accuracy: 0.3289
# Epoch 1: val_accuracy improved from -inf to 0.34615, saving model to model3.h5
# 37/37 [==============================] - 20s 239ms/step - loss: 3.0455 - accuracy: 0.3289 - val_loss: 1.2183 - val_accuracy: 0.3462
# Epoch 2/100
# 37/37 [==============================] - ETA: 0s - loss: 1.1311 - accuracy: 0.3135
# Epoch 2: val_accuracy did not improve from 0.34615
# 37/37 [==============================] - 4s 124ms/step - loss: 1.1311 - accuracy: 0.3135 - val_loss: 1.1032 - val_accuracy: 0.2747
# Epoch 3/100
# 37/37 [==============================] - ETA: 0s - loss: 1.1003 - accuracy: 0.3322
# Epoch 3: val_accuracy improved from 0.34615 to 0.37912, saving model to model3.h5
# 37/37 [==============================] - 5s 120ms/step - loss: 1.1003 - accuracy: 0.3322 - val_loss: 1.0993 - val_accuracy: 0.3791
# Epoch 4/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0999 - accuracy: 0.3295
# Epoch 4: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 4s 111ms/step - loss: 1.0999 - accuracy: 0.3295 - val_loss: 1.0991 - val_accuracy: 0.3791
# Epoch 5/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0995 - accuracy: 0.3427
# Epoch 5: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 2s 56ms/step - loss: 1.0995 - accuracy: 0.3427 - val_loss: 1.0990 - val_accuracy: 0.3791
# Epoch 6/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0997 - accuracy: 0.3217
# Epoch 6: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 3s 79ms/step - loss: 1.0997 - accuracy: 0.3217 - val_loss: 1.0994 - val_accuracy: 0.3791
# Epoch 7/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0999 - accuracy: 0.3317
# Epoch 7: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 2s 62ms/step - loss: 1.0999 - accuracy: 0.3317 - val_loss: 1.0987 - val_accuracy: 0.3462
# Epoch 8/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0996 - accuracy: 0.3300
# Epoch 8: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 2s 63ms/step - loss: 1.0996 - accuracy: 0.3300 - val_loss: 1.0993 - val_accuracy: 0.3462
# Epoch 9/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0995 - accuracy: 0.3240
# Epoch 9: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 2s 67ms/step - loss: 1.0995 - accuracy: 0.3240 - val_loss: 1.0989 - val_accuracy: 0.3462
# Epoch 10/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0993 - accuracy: 0.3383
# Epoch 10: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 1s 31ms/step - loss: 1.0993 - accuracy: 0.3383 - val_loss: 1.0989 - val_accuracy: 0.3462
# Epoch 11/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.0995 - accuracy: 0.3103
# Epoch 11: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 1s 20ms/step - loss: 1.0995 - accuracy: 0.3135 - val_loss: 1.0987 - val_accuracy: 0.3462
# Epoch 12/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0997 - accuracy: 0.3245
# Epoch 12: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 1s 36ms/step - loss: 1.0997 - accuracy: 0.3245 - val_loss: 1.0995 - val_accuracy: 0.3462
# Epoch 13/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0995 - accuracy: 0.3422
# Epoch 13: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 1s 31ms/step - loss: 1.0995 - accuracy: 0.3422 - val_loss: 1.0991 - val_accuracy: 0.3462
# Epoch 14/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0998 - accuracy: 0.3278
# Epoch 14: val_accuracy did not improve from 0.37912
# 37/37 [==============================] - 1s 33ms/step - loss: 1.0998 - accuracy: 0.3278 - val_loss: 1.0988 - val_accuracy: 0.3462
# Epoch 15/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0991 - accuracy: 0.3703
# Epoch 15: val_accuracy improved from 0.37912 to 0.46154, saving model to model3.h5
# 37/37 [==============================] - 1s 34ms/step - loss: 1.0991 - accuracy: 0.3703 - val_loss: 1.0969 - val_accuracy: 0.4615
# Epoch 16/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0974 - accuracy: 0.3714
# Epoch 16: val_accuracy improved from 0.46154 to 0.49451, saving model to model3.h5
# 37/37 [==============================] - 1s 22ms/step - loss: 1.0974 - accuracy: 0.3714 - val_loss: 1.0917 - val_accuracy: 0.4945
# Epoch 17/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0904 - accuracy: 0.5121
# Epoch 17: val_accuracy improved from 0.49451 to 0.58791, saving model to model3.h5
# 37/37 [==============================] - 1s 22ms/step - loss: 1.0904 - accuracy: 0.5121 - val_loss: 1.0786 - val_accuracy: 0.5879
# Epoch 18/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0716 - accuracy: 0.6269
# Epoch 18: val_accuracy improved from 0.58791 to 0.60440, saving model to model3.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 1.0716 - accuracy: 0.6269 - val_loss: 1.0610 - val_accuracy: 0.6044
# Epoch 19/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0555 - accuracy: 0.6302
# Epoch 19: val_accuracy improved from 0.60440 to 0.62088, saving model to model3.h5
# 37/37 [==============================] - 1s 20ms/step - loss: 1.0555 - accuracy: 0.6302 - val_loss: 1.0380 - val_accuracy: 0.6209
# Epoch 20/100
# 31/37 [========================>.....] - ETA: 0s - loss: 1.0456 - accuracy: 0.6077
# Epoch 20: val_accuracy did not improve from 0.62088
# 37/37 [==============================] - 1s 26ms/step - loss: 1.0412 - accuracy: 0.6076 - val_loss: 1.0167 - val_accuracy: 0.6044
# Epoch 21/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.0103 - accuracy: 0.6154
# Epoch 21: val_accuracy improved from 0.62088 to 0.63736, saving model to model3.h5
# 37/37 [==============================] - 1s 33ms/step - loss: 1.0093 - accuracy: 0.6170 - val_loss: 0.9936 - val_accuracy: 0.6374
# Epoch 22/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.9839 - accuracy: 0.6106
# Epoch 22: val_accuracy improved from 0.63736 to 0.64286, saving model to model3.h5
# 37/37 [==============================] - 1s 33ms/step - loss: 0.9832 - accuracy: 0.6098 - val_loss: 0.9632 - val_accuracy: 0.6429
# Epoch 23/100
# 37/37 [==============================] - ETA: 0s - loss: 0.9590 - accuracy: 0.6374
# Epoch 23: val_accuracy did not improve from 0.64286
# 37/37 [==============================] - 1s 28ms/step - loss: 0.9590 - accuracy: 0.6374 - val_loss: 0.9584 - val_accuracy: 0.6319
# Epoch 24/100
# 37/37 [==============================] - ETA: 0s - loss: 0.9404 - accuracy: 0.6380
# Epoch 24: val_accuracy improved from 0.64286 to 0.65934, saving model to model3.h5
# 37/37 [==============================] - 1s 19ms/step - loss: 0.9404 - accuracy: 0.6380 - val_loss: 0.9032 - val_accuracy: 0.6593
# Epoch 25/100
# 37/37 [==============================] - ETA: 0s - loss: 0.9033 - accuracy: 0.6313
# Epoch 25: val_accuracy did not improve from 0.65934
# 37/37 [==============================] - 1s 20ms/step - loss: 0.9033 - accuracy: 0.6313 - val_loss: 0.8676 - val_accuracy: 0.6429
# Epoch 26/100
# 35/37 [===========================>..] - ETA: 0s - loss: 0.8753 - accuracy: 0.6657
# Epoch 26: val_accuracy improved from 0.65934 to 0.75824, saving model to model3.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 0.8740 - accuracy: 0.6667 - val_loss: 0.8517 - val_accuracy: 0.7582
# Epoch 27/100
# 37/37 [==============================] - ETA: 0s - loss: 0.8584 - accuracy: 0.6523
# Epoch 27: val_accuracy did not improve from 0.75824
# 37/37 [==============================] - 1s 14ms/step - loss: 0.8584 - accuracy: 0.6523 - val_loss: 0.8408 - val_accuracy: 0.6978
# Epoch 28/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.8483 - accuracy: 0.6618
# Epoch 28: val_accuracy did not improve from 0.75824
# 37/37 [==============================] - 0s 13ms/step - loss: 0.8495 - accuracy: 0.6634 - val_loss: 0.8231 - val_accuracy: 0.7143
# Epoch 29/100
# 33/37 [=========================>....] - ETA: 0s - loss: 0.8202 - accuracy: 0.6745
# Epoch 29: val_accuracy did not improve from 0.75824
# 37/37 [==============================] - 0s 12ms/step - loss: 0.8236 - accuracy: 0.6700 - val_loss: 0.7907 - val_accuracy: 0.7308
# Epoch 30/100
# 35/37 [===========================>..] - ETA: 0s - loss: 0.7922 - accuracy: 0.7074
# Epoch 30: val_accuracy did not improve from 0.75824
# 37/37 [==============================] - 0s 7ms/step - loss: 0.7952 - accuracy: 0.7075 - val_loss: 0.8348 - val_accuracy: 0.6154
# Epoch 31/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7861 - accuracy: 0.7009
# Epoch 31: val_accuracy improved from 0.75824 to 0.78022, saving model to model3.h5
# 37/37 [==============================] - 1s 26ms/step - loss: 0.7861 - accuracy: 0.7009 - val_loss: 0.7964 - val_accuracy: 0.7802
# Epoch 32/100
# 37/37 [==============================] - ETA: 0s - loss: 0.8036 - accuracy: 0.7180
# Epoch 32: val_accuracy did not improve from 0.78022
# 37/37 [==============================] - 1s 19ms/step - loss: 0.8036 - accuracy: 0.7180 - val_loss: 0.7691 - val_accuracy: 0.7198
# Epoch 33/100
# 32/37 [========================>.....] - ETA: 0s - loss: 0.7897 - accuracy: 0.7206
# Epoch 33: val_accuracy improved from 0.78022 to 0.80220, saving model to model3.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 0.7811 - accuracy: 0.7252 - val_loss: 0.7425 - val_accuracy: 0.8022
# Epoch 34/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.7616 - accuracy: 0.7165
# Epoch 34: val_accuracy did not improve from 0.80220
# 37/37 [==============================] - 0s 7ms/step - loss: 0.7629 - accuracy: 0.7158 - val_loss: 0.7611 - val_accuracy: 0.7857
# Epoch 35/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7674 - accuracy: 0.7252
# Epoch 35: val_accuracy did not improve from 0.80220
# 37/37 [==============================] - 1s 19ms/step - loss: 0.7674 - accuracy: 0.7252 - val_loss: 0.7517 - val_accuracy: 0.7802
# Epoch 36/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7557 - accuracy: 0.7268
# Epoch 36: val_accuracy improved from 0.80220 to 0.82418, saving model to model3.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 0.7557 - accuracy: 0.7268 - val_loss: 0.6986 - val_accuracy: 0.8242
# Epoch 37/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7352 - accuracy: 0.7373
# Epoch 37: val_accuracy improved from 0.82418 to 0.84066, saving model to model3.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 0.7352 - accuracy: 0.7373 - val_loss: 0.6994 - val_accuracy: 0.8407
# Epoch 38/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7307 - accuracy: 0.7445
# Epoch 38: val_accuracy did not improve from 0.84066
# 37/37 [==============================] - 0s 7ms/step - loss: 0.7307 - accuracy: 0.7445 - val_loss: 0.6922 - val_accuracy: 0.8242
# Epoch 39/100
# 37/37 [==============================] - ETA: 0s - loss: 0.7045 - accuracy: 0.7616
# Epoch 39: val_accuracy did not improve from 0.84066
# 37/37 [==============================] - 0s 13ms/step - loss: 0.7045 - accuracy: 0.7616 - val_loss: 0.6815 - val_accuracy: 0.8297
# Epoch 40/100
# 35/37 [===========================>..] - ETA: 0s - loss: 0.6990 - accuracy: 0.7674
# Epoch 40: val_accuracy did not improve from 0.84066
# 37/37 [==============================] - 0s 7ms/step - loss: 0.6986 - accuracy: 0.7688 - val_loss: 0.6620 - val_accuracy: 0.8352
# Epoch 41/100
# 36/37 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.7522
# Epoch 41: val_accuracy improved from 0.84066 to 0.84615, saving model to model3.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 0.7099 - accuracy: 0.7528 - val_loss: 0.6872 - val_accuracy: 0.8462
# Epoch 42/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6814 - accuracy: 0.7903
# Epoch 42: val_accuracy improved from 0.84615 to 0.85165, saving model to model3.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 0.6814 - accuracy: 0.7903 - val_loss: 0.6527 - val_accuracy: 0.8516
# Epoch 43/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6836 - accuracy: 0.7770
# Epoch 43: val_accuracy improved from 0.85165 to 0.85714, saving model to model3.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 0.6836 - accuracy: 0.7770 - val_loss: 0.6684 - val_accuracy: 0.8571
# Epoch 44/100
# 36/37 [============================>.] - ETA: 0s - loss: 0.6772 - accuracy: 0.7700
# Epoch 44: val_accuracy improved from 0.85714 to 0.86264, saving model to model3.h5
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6772 - accuracy: 0.7693 - val_loss: 0.6296 - val_accuracy: 0.8626
# Epoch 45/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6625 - accuracy: 0.7770
# Epoch 45: val_accuracy did not improve from 0.86264
# 37/37 [==============================] - 1s 29ms/step - loss: 0.6625 - accuracy: 0.7770 - val_loss: 0.6308 - val_accuracy: 0.8297
# Epoch 46/100
# 33/37 [=========================>....] - ETA: 0s - loss: 0.7235 - accuracy: 0.7588
# Epoch 46: val_accuracy did not improve from 0.86264
# 37/37 [==============================] - 0s 10ms/step - loss: 0.7233 - accuracy: 0.7638 - val_loss: 0.6514 - val_accuracy: 0.8626
# Epoch 47/100
# 32/37 [========================>.....] - ETA: 0s - loss: 0.6682 - accuracy: 0.8044
# Epoch 47: val_accuracy did not improve from 0.86264
# 37/37 [==============================] - 1s 18ms/step - loss: 0.6625 - accuracy: 0.8063 - val_loss: 0.6312 - val_accuracy: 0.8571
# Epoch 48/100
# 36/37 [============================>.] - ETA: 0s - loss: 0.6554 - accuracy: 0.8022
# Epoch 48: val_accuracy improved from 0.86264 to 0.89011, saving model to model3.h5
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6561 - accuracy: 0.8019 - val_loss: 0.6076 - val_accuracy: 0.8901
# Epoch 49/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6437 - accuracy: 0.8074
# Epoch 49: val_accuracy did not improve from 0.89011
# 37/37 [==============================] - 1s 22ms/step - loss: 0.6437 - accuracy: 0.8074 - val_loss: 0.6319 - val_accuracy: 0.8846
# Epoch 50/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.6451 - accuracy: 0.7888
# Epoch 50: val_accuracy did not improve from 0.89011
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6444 - accuracy: 0.7908 - val_loss: 0.5940 - val_accuracy: 0.8901
# Epoch 51/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6284 - accuracy: 0.8129
# Epoch 51: val_accuracy improved from 0.89011 to 0.89560, saving model to model3.h5
# 37/37 [==============================] - 1s 22ms/step - loss: 0.6284 - accuracy: 0.8129 - val_loss: 0.6035 - val_accuracy: 0.8956
# Epoch 52/100
# 35/37 [===========================>..] - ETA: 0s - loss: 0.6266 - accuracy: 0.8126
# Epoch 52: val_accuracy improved from 0.89560 to 0.90110, saving model to model3.h5
# 37/37 [==============================] - 0s 9ms/step - loss: 0.6296 - accuracy: 0.8129 - val_loss: 0.5874 - val_accuracy: 0.9011
# Epoch 53/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6347 - accuracy: 0.7986
# Epoch 53: val_accuracy improved from 0.90110 to 0.92308, saving model to model3.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 0.6347 - accuracy: 0.7986 - val_loss: 0.5745 - val_accuracy: 0.9231
# Epoch 54/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6386 - accuracy: 0.8228
# Epoch 54: val_accuracy did not improve from 0.92308
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6386 - accuracy: 0.8228 - val_loss: 0.5759 - val_accuracy: 0.9176
# Epoch 55/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6026 - accuracy: 0.8306
# Epoch 55: val_accuracy did not improve from 0.92308
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6026 - accuracy: 0.8306 - val_loss: 0.5655 - val_accuracy: 0.9176
# Epoch 56/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5899 - accuracy: 0.8422
# Epoch 56: val_accuracy did not improve from 0.92308
# 37/37 [==============================] - 0s 13ms/step - loss: 0.5899 - accuracy: 0.8422 - val_loss: 0.5646 - val_accuracy: 0.9176
# Epoch 57/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6043 - accuracy: 0.8372
# Epoch 57: val_accuracy did not improve from 0.92308
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6043 - accuracy: 0.8372 - val_loss: 0.6293 - val_accuracy: 0.8791
# Epoch 58/100
# 37/37 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.8499
# Epoch 58: val_accuracy did not improve from 0.92308
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6039 - accuracy: 0.8499 - val_loss: 0.5643 - val_accuracy: 0.9011
# Epoch 59/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.6008 - accuracy: 0.8518
# Epoch 59: val_accuracy improved from 0.92308 to 0.92857, saving model to model3.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 0.6045 - accuracy: 0.8526 - val_loss: 0.5516 - val_accuracy: 0.9286
# Epoch 60/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5977 - accuracy: 0.8333
# Epoch 60: val_accuracy did not improve from 0.92857
# 37/37 [==============================] - 1s 19ms/step - loss: 0.5977 - accuracy: 0.8333 - val_loss: 0.5561 - val_accuracy: 0.9121
# Epoch 61/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5655 - accuracy: 0.8687
# Epoch 61: val_accuracy improved from 0.92857 to 0.94505, saving model to model3.h5
# 37/37 [==============================] - 1s 26ms/step - loss: 0.5655 - accuracy: 0.8687 - val_loss: 0.5331 - val_accuracy: 0.9451
# Epoch 62/100
# 36/37 [============================>.] - ETA: 0s - loss: 0.5894 - accuracy: 0.8694
# Epoch 62: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5894 - accuracy: 0.8698 - val_loss: 0.5321 - val_accuracy: 0.9341
# Epoch 63/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.8554
# Epoch 63: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 1s 18ms/step - loss: 0.5838 - accuracy: 0.8554 - val_loss: 0.5365 - val_accuracy: 0.9396
# Epoch 64/100
# 36/37 [============================>.] - ETA: 0s - loss: 0.5709 - accuracy: 0.8717
# Epoch 64: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5701 - accuracy: 0.8720 - val_loss: 0.5389 - val_accuracy: 0.9286
# Epoch 65/100
# 28/37 [=====================>........] - ETA: 0s - loss: 0.5473 - accuracy: 0.8779
# Epoch 65: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5524 - accuracy: 0.8791 - val_loss: 0.5329 - val_accuracy: 0.9286
# Epoch 66/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.6417 - accuracy: 0.8541
# Epoch 66: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6367 - accuracy: 0.8560 - val_loss: 0.5156 - val_accuracy: 0.9341
# Epoch 67/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5340 - accuracy: 0.8896
# Epoch 67: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 13ms/step - loss: 0.5340 - accuracy: 0.8896 - val_loss: 0.5046 - val_accuracy: 0.9341
# Epoch 68/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5617 - accuracy: 0.8841
# Epoch 68: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 1s 23ms/step - loss: 0.5617 - accuracy: 0.8841 - val_loss: 0.5313 - val_accuracy: 0.9231
# Epoch 69/100
# 33/37 [=========================>....] - ETA: 0s - loss: 0.5669 - accuracy: 0.8921
# Epoch 69: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 1s 18ms/step - loss: 0.5622 - accuracy: 0.8935 - val_loss: 0.4864 - val_accuracy: 0.9341
# Epoch 70/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.8935
# Epoch 70: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 1s 18ms/step - loss: 0.5257 - accuracy: 0.8935 - val_loss: 0.4868 - val_accuracy: 0.9451
# Epoch 71/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5447 - accuracy: 0.8880
# Epoch 71: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 1s 18ms/step - loss: 0.5447 - accuracy: 0.8880 - val_loss: 0.4826 - val_accuracy: 0.9341
# Epoch 72/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5220 - accuracy: 0.8990
# Epoch 72: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 9ms/step - loss: 0.5220 - accuracy: 0.8990 - val_loss: 0.4814 - val_accuracy: 0.9396
# Epoch 73/100
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5132 - accuracy: 0.8960
# Epoch 73: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 9ms/step - loss: 0.5115 - accuracy: 0.8962 - val_loss: 0.4979 - val_accuracy: 0.9451
# Epoch 74/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4974 - accuracy: 0.9150
# Epoch 74: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 9ms/step - loss: 0.4974 - accuracy: 0.9150 - val_loss: 0.4863 - val_accuracy: 0.9341
# Epoch 75/100
# 31/37 [========================>.....] - ETA: 0s - loss: 0.5005 - accuracy: 0.9032
# Epoch 75: val_accuracy did not improve from 0.94505
# 37/37 [==============================] - 0s 8ms/step - loss: 0.5014 - accuracy: 0.9040 - val_loss: 0.4874 - val_accuracy: 0.9451
# Epoch 76/100
# 32/37 [========================>.....] - ETA: 0s - loss: 0.5254 - accuracy: 0.8944
# Epoch 76: val_accuracy improved from 0.94505 to 0.95604, saving model to model3.h5
# 37/37 [==============================] - 1s 20ms/step - loss: 0.5215 - accuracy: 0.8940 - val_loss: 0.4361 - val_accuracy: 0.9560
# Epoch 77/100
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5171 - accuracy: 0.9069
# Epoch 77: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5142 - accuracy: 0.9084 - val_loss: 0.4594 - val_accuracy: 0.9451
# Epoch 78/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5154 - accuracy: 0.9056
# Epoch 78: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5154 - accuracy: 0.9056 - val_loss: 0.4567 - val_accuracy: 0.9505
# Epoch 79/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5006 - accuracy: 0.9001
# Epoch 79: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 1s 19ms/step - loss: 0.5006 - accuracy: 0.9001 - val_loss: 0.4448 - val_accuracy: 0.9451
# Epoch 80/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.9150
# Epoch 80: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4995 - accuracy: 0.9150 - val_loss: 0.4271 - val_accuracy: 0.9505
# Epoch 81/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.5010 - accuracy: 0.9129
# Epoch 81: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4963 - accuracy: 0.9145 - val_loss: 0.4635 - val_accuracy: 0.9231
# Epoch 82/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4619 - accuracy: 0.9150
# Epoch 82: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4619 - accuracy: 0.9150 - val_loss: 0.4235 - val_accuracy: 0.9560
# Epoch 83/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4863 - accuracy: 0.9238
# Epoch 83: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4863 - accuracy: 0.9238 - val_loss: 0.4581 - val_accuracy: 0.9341
# Epoch 84/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.9183
# Epoch 84: val_accuracy did not improve from 0.95604
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4659 - accuracy: 0.9183 - val_loss: 0.4390 - val_accuracy: 0.9451
# Epoch 85/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.9189
# Epoch 85: val_accuracy improved from 0.95604 to 0.96154, saving model to model3.h5
# 37/37 [==============================] - 1s 21ms/step - loss: 0.4816 - accuracy: 0.9189 - val_loss: 0.3924 - val_accuracy: 0.9615
# Epoch 86/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4852 - accuracy: 0.9111
# Epoch 86: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4852 - accuracy: 0.9111 - val_loss: 0.4150 - val_accuracy: 0.9615
# Epoch 87/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.9194
# Epoch 87: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4712 - accuracy: 0.9194 - val_loss: 0.4034 - val_accuracy: 0.9615
# Epoch 88/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4633 - accuracy: 0.9216
# Epoch 88: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 1s 14ms/step - loss: 0.4633 - accuracy: 0.9216 - val_loss: 0.4442 - val_accuracy: 0.9396
# Epoch 89/100
# 32/37 [========================>.....] - ETA: 0s - loss: 0.6349 - accuracy: 0.9038
# Epoch 89: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6232 - accuracy: 0.9073 - val_loss: 0.4745 - val_accuracy: 0.9505
# Epoch 90/100
# 34/37 [==========================>...] - ETA: 0s - loss: 0.4970 - accuracy: 0.9171
# Epoch 90: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4902 - accuracy: 0.9183 - val_loss: 0.4052 - val_accuracy: 0.9505
# Epoch 91/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4429 - accuracy: 0.9260
# Epoch 91: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4429 - accuracy: 0.9260 - val_loss: 0.4026 - val_accuracy: 0.9451
# Epoch 92/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4491 - accuracy: 0.9216
# Epoch 92: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4491 - accuracy: 0.9216 - val_loss: 0.3977 - val_accuracy: 0.9396
# Epoch 93/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.9249
# Epoch 93: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4533 - accuracy: 0.9249 - val_loss: 0.4096 - val_accuracy: 0.9560
# Epoch 94/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4448 - accuracy: 0.9277
# Epoch 94: val_accuracy did not improve from 0.96154
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4448 - accuracy: 0.9277 - val_loss: 0.3758 - val_accuracy: 0.9505
# Epoch 95/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4310 - accuracy: 0.9216
# Epoch 95: val_accuracy improved from 0.96154 to 0.96703, saving model to model3.h5
# 37/37 [==============================] - 0s 9ms/step - loss: 0.4310 - accuracy: 0.9216 - val_loss: 0.4065 - val_accuracy: 0.9670
# Epoch 96/100
# 36/37 [============================>.] - ETA: 0s - loss: 0.4473 - accuracy: 0.9183
# Epoch 96: val_accuracy did not improve from 0.96703
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4463 - accuracy: 0.9189 - val_loss: 0.3750 - val_accuracy: 0.9615
# Epoch 97/100
# 36/37 [============================>.] - ETA: 0s - loss: 0.4130 - accuracy: 0.9333
# Epoch 97: val_accuracy did not improve from 0.96703
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4132 - accuracy: 0.9327 - val_loss: 0.3660 - val_accuracy: 0.9451
# Epoch 98/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4332 - accuracy: 0.9321
# Epoch 98: val_accuracy did not improve from 0.96703
# 37/37 [==============================] - 1s 24ms/step - loss: 0.4332 - accuracy: 0.9321 - val_loss: 0.3791 - val_accuracy: 0.9560
# Epoch 99/100
# 31/37 [========================>.....] - ETA: 0s - loss: 0.4262 - accuracy: 0.9258
# Epoch 99: val_accuracy did not improve from 0.96703
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4330 - accuracy: 0.9255 - val_loss: 0.3698 - val_accuracy: 0.9615
# Epoch 100/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4260 - accuracy: 0.9294
# Epoch 100: val_accuracy improved from 0.96703 to 0.97253, saving model to model3.h5
# 37/37 [==============================] - 1s 21ms/step - loss: 0.4260 - accuracy: 0.9294 - val_loss: 0.3569 - val_accuracy: 0.9725

# %%
from keras.saving.saving_api import load_model
model_1=load_model('model3.h5')

# %%
dff=pd.read_excel('/content/drive/MyDrive/DryBulk_MarketNews_v2_20220916.xlsx')
dff = dff[['Sent_Text', 'Sentiment']]
dff.head(5)
# Out:
#                                            Sent_Text Sentiment
# 0  VIETNAM PRODUCED 4.48 MT OF COAL IN JUL, UP 3....  Negative
# 1  INDIA'S WHEAT CROP IN 2022-23 IS REVISED DOWN ...  Negative
# 2  CHINA’S STEEL INDUSTRY WHICH RELIES AT LEAST 1...  Negative
# 3  RECORD LOW LVL OF RHINE RIVER(IN SOME CASES, V...  Negative
# 4  FIRST GRAIN SHIPMENT EX UKRAINE PASSED INSPECT...  Positive

# %%
def clean_str(in_str):
    in_str = str(in_str)
    # replace urls with 'url'
    in_str = re.sub(r"(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9]\.[^\s]{2,})", "url", in_str)
    in_str = re.sub(r'([^\s\w]|_)+', '', in_str)
    return in_str.strip().lower()


dff['SentText'] = dff['Sent_Text'].apply(clean_str)

# %%
dff[dff['Sentiment'] == 'Nagative']
# Out:
#                                             Sent_Text Sentiment  \
# 29  COAL EXPORTS FROM Q'LAND IN JUL WAS 15.26 MT, ...  Nagative
#
#                                              SentText
# 29  coal exports from qland in jul was 1526 mt dow...

# %%
dff.iloc[29]["Sentiment"]="Negative"

# %%
dff['Sentiment']=dff['Sentiment'].str.lower()

# %%
#dff[dff['Sentiment'] == 'negative']

# %%
test_seq = tokenizer.texts_to_sequences(dff['SentText'].values)
X_test = pad_sequences(test_seq, maxlen=sequence_length,padding='post')
y_test = pd.get_dummies(dff['Sentiment']).values
y_pred = model_1.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 11ms/step

# %%
accuracy_score(list(map(lambda x: np.argmax(x), y_test)), list(map(lambda x: np.argmax(x), y_pred)))*100
# Out:
# 56.22119815668203

# %%
print(classification_report(list(map(lambda x: np.argmax(x), y_test)), list(map(lambda x: np.argmax(x), y_pred))))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.74      0.66        97
#            1       0.15      0.09      0.11        22
#            2       0.58      0.49      0.53        98
#
#     accuracy                           0.56       217
#    macro avg       0.44      0.44      0.44       217
# weighted avg       0.54      0.56      0.55       217

# %%
embeddings_index = {}
f = open(os.path.join('/content/drive/MyDrive/Colab Notebooks/archive (11)/glove.6B.200d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 6168 unique tokens.

# %%
num_words = min(max_features, len(word_index)) + 1
print(num_words)

# first create a matrix of zeros, this is our embedding matrix
embedding_matrix = np.zeros((num_words, embedding_dim))

# for each word in out tokenizer lets try to find that work in our w2v model
for word, i in word_index.items():
    if i > max_features:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # we found the word - add that words vector to the matrix
        embedding_matrix[i] = embedding_vector
    else:
        # doesn't exist, assign a random vector
        embedding_matrix[i] = np.random.randn(embedding_dim)
# Out:
# 6169

# %%
inputs_2 = Input(shape=(sequence_length,), dtype='int32')

# note the `trainable=False`, later we will make this layer trainable
embedding_layer_2 = Embedding(num_words,
                            embedding_dim,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=sequence_length,
                            trainable=False)(inputs_2)

reshape_2 = Reshape((sequence_length, embedding_dim, 1))(embedding_layer_2)

conv_0_2 = Conv2D(num_filters, kernel_size=(3, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape_2)
conv_1_2 = Conv2D(num_filters, kernel_size=(4, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape_2)
conv_2_2 = Conv2D(num_filters, kernel_size=(5, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape_2)
maxpool_0_2 = MaxPool2D(pool_size=(sequence_length - 3 + 1, 1), strides=(1,1), padding='valid')(conv_0_2)
maxpool_1_2 = MaxPool2D(pool_size=(sequence_length - 4 + 1, 1), strides=(1,1), padding='valid')(conv_1_2)
maxpool_2_2 = MaxPool2D(pool_size=(sequence_length - 5 + 1, 1), strides=(1,1), padding='valid')(conv_2_2)

concatenated_tensor_2 = Concatenate(axis=1)([maxpool_0_2, maxpool_1_2, maxpool_2_2])
flatten_2 = Flatten()(concatenated_tensor_2)

dropout_2 = Dropout(0.5)(flatten_2)
output_2 = Dense(units=3, activation='softmax')(dropout_2)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
ck=ModelCheckpoint("model4.h5",monitor="val_accuracy",save_best_only=True,verbose=1)

# %%
model_2 = Model(inputs=inputs_2, outputs=output_2)
model_2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model_2.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 55)]         0           []
#
#  embedding_1 (Embedding)        (None, 55, 200)      1233800     ['input_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 55, 200, 1)   0           ['embedding_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 53, 1, 100)   60100       ['reshape_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 52, 1, 100)   80100       ['reshape_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 51, 1, 100)   100100      ['reshape_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 3, 1, 100)    0           ['max_pooling2d_3[0][0]',
#                                                                   'max_pooling2d_4[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  flatten_1 (Flatten)            (None, 300)          0           ['concatenate_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 300)          0           ['flatten_1[0][0]']
#
#  dense_1 (Dense)                (None, 3)            903         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1,475,003
# Trainable params: 241,203
# Non-trainable params: 1,233,800
# __________________________________________________________________________________________________
# None

# %%
batch_size=50
history_2 = model_2.fit(X, y, epochs=100, batch_size=batch_size, verbose=1, validation_data=(X_test,y_test), shuffle=True, callbacks=[ck])
# Out:
# Epoch 1/100
# 35/37 [===========================>..] - ETA: 0s - loss: 3.2230 - accuracy: 0.4080
# Epoch 1: val_accuracy improved from -inf to 0.44700, saving model to model4.h5
# 37/37 [==============================] - 3s 44ms/step - loss: 3.1594 - accuracy: 0.4150 - val_loss: 1.3837 - val_accuracy: 0.4470
# Epoch 2/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2913 - accuracy: 0.4212
# Epoch 2: val_accuracy did not improve from 0.44700
# 37/37 [==============================] - 0s 7ms/step - loss: 1.2900 - accuracy: 0.4227 - val_loss: 1.3060 - val_accuracy: 0.4147
# Epoch 3/100
# 37/37 [==============================] - ETA: 0s - loss: 1.2828 - accuracy: 0.4321
# Epoch 3: val_accuracy did not improve from 0.44700
# 37/37 [==============================] - 0s 7ms/step - loss: 1.2828 - accuracy: 0.4321 - val_loss: 1.3459 - val_accuracy: 0.1382
# Epoch 4/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2965 - accuracy: 0.4381
# Epoch 4: val_accuracy did not improve from 0.44700
# 37/37 [==============================] - 0s 7ms/step - loss: 1.2951 - accuracy: 0.4432 - val_loss: 1.3607 - val_accuracy: 0.1429
# Epoch 5/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.3119 - accuracy: 0.4476
# Epoch 5: val_accuracy did not improve from 0.44700
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3094 - accuracy: 0.4509 - val_loss: 1.3616 - val_accuracy: 0.1429
# Epoch 6/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.3104 - accuracy: 0.4479
# Epoch 6: val_accuracy improved from 0.44700 to 0.45161, saving model to model4.h5
# 37/37 [==============================] - 1s 35ms/step - loss: 1.3113 - accuracy: 0.4443 - val_loss: 1.3142 - val_accuracy: 0.4516
# Epoch 7/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.3263 - accuracy: 0.4406
# Epoch 7: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3265 - accuracy: 0.4376 - val_loss: 1.3743 - val_accuracy: 0.3687
# Epoch 8/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.3412 - accuracy: 0.4500
# Epoch 8: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3370 - accuracy: 0.4514 - val_loss: 1.4088 - val_accuracy: 0.3917
# Epoch 9/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.3363 - accuracy: 0.4538
# Epoch 9: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3340 - accuracy: 0.4581 - val_loss: 1.4091 - val_accuracy: 0.2949
# Epoch 10/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.3597 - accuracy: 0.4788
# Epoch 10: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3595 - accuracy: 0.4691 - val_loss: 1.4057 - val_accuracy: 0.4101
# Epoch 11/100
# 28/37 [=====================>........] - ETA: 0s - loss: 1.3729 - accuracy: 0.4629
# Epoch 11: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3779 - accuracy: 0.4498 - val_loss: 1.4337 - val_accuracy: 0.2903
# Epoch 12/100
# 30/37 [=======================>......] - ETA: 0s - loss: 1.4053 - accuracy: 0.4307
# Epoch 12: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3955 - accuracy: 0.4349 - val_loss: 1.3503 - val_accuracy: 0.4516
# Epoch 13/100
# 29/37 [======================>.......] - ETA: 0s - loss: 1.3553 - accuracy: 0.4552
# Epoch 13: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3541 - accuracy: 0.4592 - val_loss: 1.3335 - val_accuracy: 0.4470
# Epoch 14/100
# 37/37 [==============================] - ETA: 0s - loss: 1.3710 - accuracy: 0.4421
# Epoch 14: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 8ms/step - loss: 1.3710 - accuracy: 0.4421 - val_loss: 1.4039 - val_accuracy: 0.4424
# Epoch 15/100
# 29/37 [======================>.......] - ETA: 0s - loss: 1.4233 - accuracy: 0.4200
# Epoch 15: val_accuracy did not improve from 0.45161
# 37/37 [==============================] - 0s 7ms/step - loss: 1.4108 - accuracy: 0.4321 - val_loss: 1.5044 - val_accuracy: 0.1060
# Epoch 16/100
# 37/37 [==============================] - ETA: 0s - loss: 1.3831 - accuracy: 0.4509
# Epoch 16: val_accuracy improved from 0.45161 to 0.47005, saving model to model4.h5
# 37/37 [==============================] - 2s 60ms/step - loss: 1.3831 - accuracy: 0.4509 - val_loss: 1.3880 - val_accuracy: 0.4700
# Epoch 17/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.3879 - accuracy: 0.4625
# Epoch 17: val_accuracy improved from 0.47005 to 0.47465, saving model to model4.h5
# 37/37 [==============================] - 1s 38ms/step - loss: 1.3867 - accuracy: 0.4592 - val_loss: 1.3849 - val_accuracy: 0.4747
# Epoch 18/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.3616 - accuracy: 0.4491
# Epoch 18: val_accuracy did not improve from 0.47465
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3611 - accuracy: 0.4520 - val_loss: 1.4056 - val_accuracy: 0.4562
# Epoch 19/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.4160 - accuracy: 0.4519
# Epoch 19: val_accuracy did not improve from 0.47465
# 37/37 [==============================] - 0s 6ms/step - loss: 1.4080 - accuracy: 0.4514 - val_loss: 1.3312 - val_accuracy: 0.4470
# Epoch 20/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.3539 - accuracy: 0.4606
# Epoch 20: val_accuracy did not improve from 0.47465
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3546 - accuracy: 0.4603 - val_loss: 1.4308 - val_accuracy: 0.3088
# Epoch 21/100
# 30/37 [=======================>......] - ETA: 0s - loss: 1.3647 - accuracy: 0.4733
# Epoch 21: val_accuracy did not improve from 0.47465
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3610 - accuracy: 0.4674 - val_loss: 1.4560 - val_accuracy: 0.2396
# Epoch 22/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.3821 - accuracy: 0.4539
# Epoch 22: val_accuracy did not improve from 0.47465
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3797 - accuracy: 0.4531 - val_loss: 1.4699 - val_accuracy: 0.1060
# Epoch 23/100
# 30/37 [=======================>......] - ETA: 0s - loss: 1.3506 - accuracy: 0.4793
# Epoch 23: val_accuracy improved from 0.47465 to 0.47926, saving model to model4.h5
# 37/37 [==============================] - 1s 34ms/step - loss: 1.3510 - accuracy: 0.4730 - val_loss: 1.3575 - val_accuracy: 0.4793
# Epoch 24/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.3704 - accuracy: 0.4429
# Epoch 24: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3680 - accuracy: 0.4498 - val_loss: 1.5183 - val_accuracy: 0.1060
# Epoch 25/100
# 31/37 [========================>.....] - ETA: 0s - loss: 1.3489 - accuracy: 0.4555
# Epoch 25: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3458 - accuracy: 0.4597 - val_loss: 1.4838 - val_accuracy: 0.1198
# Epoch 26/100
# 31/37 [========================>.....] - ETA: 0s - loss: 1.3991 - accuracy: 0.4329
# Epoch 26: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3887 - accuracy: 0.4376 - val_loss: 1.3298 - val_accuracy: 0.4747
# Epoch 27/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.3623 - accuracy: 0.4582
# Epoch 27: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3601 - accuracy: 0.4592 - val_loss: 1.3955 - val_accuracy: 0.3594
# Epoch 28/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.3661 - accuracy: 0.4665
# Epoch 28: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3690 - accuracy: 0.4597 - val_loss: 1.4522 - val_accuracy: 0.1659
# Epoch 29/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.3643 - accuracy: 0.4515
# Epoch 29: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3611 - accuracy: 0.4492 - val_loss: 1.4125 - val_accuracy: 0.2627
# Epoch 30/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.3482 - accuracy: 0.4519
# Epoch 30: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3383 - accuracy: 0.4641 - val_loss: 1.4220 - val_accuracy: 0.2949
# Epoch 31/100
# 30/37 [=======================>......] - ETA: 0s - loss: 1.3226 - accuracy: 0.4860
# Epoch 31: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3273 - accuracy: 0.4829 - val_loss: 1.5796 - val_accuracy: 0.1014
# Epoch 32/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.3583 - accuracy: 0.4581
# Epoch 32: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3540 - accuracy: 0.4558 - val_loss: 1.4080 - val_accuracy: 0.2396
# Epoch 33/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.3383 - accuracy: 0.4506
# Epoch 33: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3374 - accuracy: 0.4531 - val_loss: 1.3665 - val_accuracy: 0.3502
# Epoch 34/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.3159 - accuracy: 0.4731
# Epoch 34: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3126 - accuracy: 0.4801 - val_loss: 1.3506 - val_accuracy: 0.3825
# Epoch 35/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.3182 - accuracy: 0.4762
# Epoch 35: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3167 - accuracy: 0.4746 - val_loss: 1.3812 - val_accuracy: 0.3180
# Epoch 36/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.3211 - accuracy: 0.4641
# Epoch 36: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 6ms/step - loss: 1.3210 - accuracy: 0.4652 - val_loss: 1.5290 - val_accuracy: 0.1014
# Epoch 37/100
# 31/37 [========================>.....] - ETA: 0s - loss: 1.3374 - accuracy: 0.4832
# Epoch 37: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3334 - accuracy: 0.4790 - val_loss: 1.3560 - val_accuracy: 0.3733
# Epoch 38/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.3272 - accuracy: 0.4543
# Epoch 38: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 9ms/step - loss: 1.3263 - accuracy: 0.4536 - val_loss: 1.4323 - val_accuracy: 0.1382
# Epoch 39/100
# 36/37 [============================>.] - ETA: 0s - loss: 1.3297 - accuracy: 0.4778
# Epoch 39: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3292 - accuracy: 0.4779 - val_loss: 1.4452 - val_accuracy: 0.1244
# Epoch 40/100
# 29/37 [======================>.......] - ETA: 0s - loss: 1.3249 - accuracy: 0.4745
# Epoch 40: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3167 - accuracy: 0.4763 - val_loss: 1.3723 - val_accuracy: 0.3180
# Epoch 41/100
# 30/37 [=======================>......] - ETA: 0s - loss: 1.3237 - accuracy: 0.4520
# Epoch 41: val_accuracy did not improve from 0.47926
# 37/37 [==============================] - 0s 7ms/step - loss: 1.3167 - accuracy: 0.4630 - val_loss: 1.4240 - val_accuracy: 0.1982
# Epoch 42/100
# 37/37 [==============================] - ETA: 0s - loss: 1.3317 - accuracy: 0.4597
# Epoch 42: val_accuracy improved from 0.47926 to 0.54839, saving model to model4.h5
# 37/37 [==============================] - 2s 59ms/step - loss: 1.3317 - accuracy: 0.4597 - val_loss: 1.3003 - val_accuracy: 0.5484
# Epoch 43/100
# 31/37 [========================>.....] - ETA: 0s - loss: 1.3172 - accuracy: 0.4703
# Epoch 43: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 11ms/step - loss: 1.3143 - accuracy: 0.4691 - val_loss: 1.4148 - val_accuracy: 0.2028
# Epoch 44/100
# 30/37 [=======================>......] - ETA: 0s - loss: 1.3027 - accuracy: 0.4587
# Epoch 44: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 9ms/step - loss: 1.2989 - accuracy: 0.4608 - val_loss: 1.3105 - val_accuracy: 0.4839
# Epoch 45/100
# 30/37 [=======================>......] - ETA: 0s - loss: 1.3055 - accuracy: 0.4667
# Epoch 45: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 9ms/step - loss: 1.3000 - accuracy: 0.4658 - val_loss: 1.3338 - val_accuracy: 0.3871
# Epoch 46/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.3214 - accuracy: 0.4663
# Epoch 46: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.3206 - accuracy: 0.4663 - val_loss: 1.3164 - val_accuracy: 0.4931
# Epoch 47/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.2986 - accuracy: 0.4686
# Epoch 47: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.2963 - accuracy: 0.4730 - val_loss: 1.4489 - val_accuracy: 0.0968
# Epoch 48/100
# 28/37 [=====================>........] - ETA: 0s - loss: 1.3526 - accuracy: 0.4671
# Epoch 48: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.3416 - accuracy: 0.4630 - val_loss: 1.3670 - val_accuracy: 0.3180
# Epoch 49/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.2846 - accuracy: 0.4749
# Epoch 49: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.2848 - accuracy: 0.4763 - val_loss: 1.4312 - val_accuracy: 0.1060
# Epoch 50/100
# 37/37 [==============================] - ETA: 0s - loss: 1.3047 - accuracy: 0.4310
# Epoch 50: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 9ms/step - loss: 1.3047 - accuracy: 0.4310 - val_loss: 1.4723 - val_accuracy: 0.1014
# Epoch 51/100
# 37/37 [==============================] - ETA: 0s - loss: 1.2942 - accuracy: 0.4763
# Epoch 51: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.2942 - accuracy: 0.4763 - val_loss: 1.2453 - val_accuracy: 0.5207
# Epoch 52/100
# 36/37 [============================>.] - ETA: 0s - loss: 1.3046 - accuracy: 0.4467
# Epoch 52: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.3041 - accuracy: 0.4470 - val_loss: 1.4562 - val_accuracy: 0.1060
# Epoch 53/100
# 37/37 [==============================] - ETA: 0s - loss: 1.2972 - accuracy: 0.4459
# Epoch 53: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.2972 - accuracy: 0.4459 - val_loss: 1.3721 - val_accuracy: 0.2212
# Epoch 54/100
# 37/37 [==============================] - ETA: 0s - loss: 1.2719 - accuracy: 0.4575
# Epoch 54: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 9ms/step - loss: 1.2719 - accuracy: 0.4575 - val_loss: 1.3757 - val_accuracy: 0.2120
# Epoch 55/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2727 - accuracy: 0.4762
# Epoch 55: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2716 - accuracy: 0.4779 - val_loss: 1.3026 - val_accuracy: 0.3825
# Epoch 56/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2706 - accuracy: 0.4921
# Epoch 56: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2726 - accuracy: 0.4868 - val_loss: 1.3657 - val_accuracy: 0.2627
# Epoch 57/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2875 - accuracy: 0.4600
# Epoch 57: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2837 - accuracy: 0.4647 - val_loss: 1.3690 - val_accuracy: 0.3318
# Epoch 58/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2923 - accuracy: 0.4727
# Epoch 58: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2910 - accuracy: 0.4719 - val_loss: 1.3536 - val_accuracy: 0.2535
# Epoch 59/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2900 - accuracy: 0.4519
# Epoch 59: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2860 - accuracy: 0.4531 - val_loss: 1.2632 - val_accuracy: 0.4931
# Epoch 60/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.2850 - accuracy: 0.4571
# Epoch 60: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2836 - accuracy: 0.4570 - val_loss: 1.2619 - val_accuracy: 0.5346
# Epoch 61/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2725 - accuracy: 0.4656
# Epoch 61: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2716 - accuracy: 0.4691 - val_loss: 1.2855 - val_accuracy: 0.4839
# Epoch 62/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2725 - accuracy: 0.4629
# Epoch 62: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2698 - accuracy: 0.4685 - val_loss: 1.3082 - val_accuracy: 0.3318
# Epoch 63/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2784 - accuracy: 0.4694
# Epoch 63: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2778 - accuracy: 0.4708 - val_loss: 1.3069 - val_accuracy: 0.4332
# Epoch 64/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2741 - accuracy: 0.4612
# Epoch 64: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2717 - accuracy: 0.4630 - val_loss: 1.3145 - val_accuracy: 0.3226
# Epoch 65/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2487 - accuracy: 0.4739
# Epoch 65: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2501 - accuracy: 0.4691 - val_loss: 1.3112 - val_accuracy: 0.3548
# Epoch 66/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2605 - accuracy: 0.4559
# Epoch 66: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2631 - accuracy: 0.4536 - val_loss: 1.2976 - val_accuracy: 0.3963
# Epoch 67/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2502 - accuracy: 0.4588
# Epoch 67: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2486 - accuracy: 0.4558 - val_loss: 1.2772 - val_accuracy: 0.4378
# Epoch 68/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2403 - accuracy: 0.4788
# Epoch 68: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2401 - accuracy: 0.4757 - val_loss: 1.3244 - val_accuracy: 0.2074
# Epoch 69/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2440 - accuracy: 0.4753
# Epoch 69: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 7ms/step - loss: 1.2442 - accuracy: 0.4713 - val_loss: 1.2821 - val_accuracy: 0.4424
# Epoch 70/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2553 - accuracy: 0.4818
# Epoch 70: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2568 - accuracy: 0.4774 - val_loss: 1.3220 - val_accuracy: 0.2442
# Epoch 71/100
# 35/37 [===========================>..] - ETA: 0s - loss: 1.2503 - accuracy: 0.4743
# Epoch 71: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2494 - accuracy: 0.4774 - val_loss: 1.3067 - val_accuracy: 0.3180
# Epoch 72/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2607 - accuracy: 0.4688
# Epoch 72: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2574 - accuracy: 0.4652 - val_loss: 1.3014 - val_accuracy: 0.3180
# Epoch 73/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2719 - accuracy: 0.4491
# Epoch 73: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2686 - accuracy: 0.4481 - val_loss: 1.3533 - val_accuracy: 0.1613
# Epoch 74/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2311 - accuracy: 0.4669
# Epoch 74: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2306 - accuracy: 0.4674 - val_loss: 1.3081 - val_accuracy: 0.3134
# Epoch 75/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2372 - accuracy: 0.4756
# Epoch 75: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2345 - accuracy: 0.4757 - val_loss: 1.2524 - val_accuracy: 0.4700
# Epoch 76/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2288 - accuracy: 0.4753
# Epoch 76: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2283 - accuracy: 0.4774 - val_loss: 1.2669 - val_accuracy: 0.3548
# Epoch 77/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2402 - accuracy: 0.4771
# Epoch 77: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2384 - accuracy: 0.4779 - val_loss: 1.3122 - val_accuracy: 0.3088
# Epoch 78/100
# 31/37 [========================>.....] - ETA: 0s - loss: 1.2390 - accuracy: 0.5006
# Epoch 78: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2384 - accuracy: 0.4950 - val_loss: 1.2413 - val_accuracy: 0.5346
# Epoch 79/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2468 - accuracy: 0.4824
# Epoch 79: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2485 - accuracy: 0.4763 - val_loss: 1.3269 - val_accuracy: 0.2811
# Epoch 80/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2600 - accuracy: 0.4856
# Epoch 80: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2572 - accuracy: 0.4823 - val_loss: 1.3547 - val_accuracy: 0.1843
# Epoch 81/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2413 - accuracy: 0.4867
# Epoch 81: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2401 - accuracy: 0.4912 - val_loss: 1.3177 - val_accuracy: 0.2903
# Epoch 82/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2425 - accuracy: 0.4800
# Epoch 82: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2395 - accuracy: 0.4851 - val_loss: 1.3757 - val_accuracy: 0.1336
# Epoch 83/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2265 - accuracy: 0.4842
# Epoch 83: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2256 - accuracy: 0.4857 - val_loss: 1.2869 - val_accuracy: 0.2627
# Epoch 84/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2356 - accuracy: 0.4776
# Epoch 84: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2324 - accuracy: 0.4829 - val_loss: 1.2713 - val_accuracy: 0.3687
# Epoch 85/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2327 - accuracy: 0.4724
# Epoch 85: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2311 - accuracy: 0.4724 - val_loss: 1.3506 - val_accuracy: 0.1751
# Epoch 86/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2241 - accuracy: 0.4952
# Epoch 86: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2236 - accuracy: 0.4983 - val_loss: 1.2816 - val_accuracy: 0.3779
# Epoch 87/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2205 - accuracy: 0.4848
# Epoch 87: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2207 - accuracy: 0.4840 - val_loss: 1.3037 - val_accuracy: 0.2903
# Epoch 88/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2304 - accuracy: 0.4800
# Epoch 88: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2297 - accuracy: 0.4763 - val_loss: 1.2415 - val_accuracy: 0.4194
# Epoch 89/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2401 - accuracy: 0.4648
# Epoch 89: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2396 - accuracy: 0.4658 - val_loss: 1.3232 - val_accuracy: 0.2719
# Epoch 90/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2130 - accuracy: 0.4871
# Epoch 90: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2095 - accuracy: 0.4906 - val_loss: 1.2372 - val_accuracy: 0.4977
# Epoch 91/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2233 - accuracy: 0.4771
# Epoch 91: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2223 - accuracy: 0.4807 - val_loss: 1.2670 - val_accuracy: 0.3825
# Epoch 92/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2318 - accuracy: 0.4825
# Epoch 92: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2278 - accuracy: 0.4862 - val_loss: 1.2418 - val_accuracy: 0.4700
# Epoch 93/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2172 - accuracy: 0.4964
# Epoch 93: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2155 - accuracy: 0.4983 - val_loss: 1.2532 - val_accuracy: 0.4424
# Epoch 94/100
# 33/37 [=========================>....] - ETA: 0s - loss: 1.2218 - accuracy: 0.4945
# Epoch 94: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2211 - accuracy: 0.4928 - val_loss: 1.2733 - val_accuracy: 0.4378
# Epoch 95/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2263 - accuracy: 0.4806
# Epoch 95: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2251 - accuracy: 0.4812 - val_loss: 1.2154 - val_accuracy: 0.5207
# Epoch 96/100
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2355 - accuracy: 0.4629
# Epoch 96: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 6ms/step - loss: 1.2343 - accuracy: 0.4636 - val_loss: 1.2485 - val_accuracy: 0.4332
# Epoch 97/100
# 32/37 [========================>.....] - ETA: 0s - loss: 1.2227 - accuracy: 0.4906
# Epoch 97: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 7ms/step - loss: 1.2177 - accuracy: 0.4950 - val_loss: 1.2735 - val_accuracy: 0.3456
# Epoch 98/100
# 29/37 [======================>.......] - ETA: 0s - loss: 1.2198 - accuracy: 0.5021
# Epoch 98: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 7ms/step - loss: 1.2230 - accuracy: 0.4917 - val_loss: 1.2649 - val_accuracy: 0.3917
# Epoch 99/100
# 31/37 [========================>.....] - ETA: 0s - loss: 1.2196 - accuracy: 0.4832
# Epoch 99: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 7ms/step - loss: 1.2162 - accuracy: 0.4840 - val_loss: 1.2383 - val_accuracy: 0.4608
# Epoch 100/100
# 37/37 [==============================] - ETA: 0s - loss: 1.2174 - accuracy: 0.4702
# Epoch 100: val_accuracy did not improve from 0.54839
# 37/37 [==============================] - 0s 8ms/step - loss: 1.2174 - accuracy: 0.4702 - val_loss: 1.2636 - val_accuracy: 0.4194

# %%
from keras.saving.saving_api import load_model
model_2=load_model('model4.h5')

# %%
test_seq = tokenizer.texts_to_sequences(dff['SentText'].values)
X_test = pad_sequences(test_seq, maxlen=sequence_length,padding='post')
y_test = pd.get_dummies(dff['Sentiment']).values
y_pred = model_2.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 4ms/step

# %%
# y_test = pd.get_dummies(dff['Sentiment'])
# print(y_test)

# %%
#print(y_pred)

# %%
accuracy_score(list(map(lambda x: np.argmax(x), y_test)), list(map(lambda x: np.argmax(x), y_pred)))*100
# Out:
# 54.83870967741935

# %%
inputs_3 = Input(shape=(sequence_length,), dtype='int32')
embedding_layer_3 = Embedding(num_words,
                            embedding_dim,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=sequence_length,
                            trainable=True)(inputs_3)

reshape_3 = Reshape((sequence_length, embedding_dim, 1))(embedding_layer_3)

# note the relu activation
conv_0_3 = Conv2D(num_filters, kernel_size=(3, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape_3)
conv_1_3 = Conv2D(num_filters, kernel_size=(4, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape_3)
conv_2_3 = Conv2D(num_filters, kernel_size=(5, embedding_dim), activation='relu', kernel_regularizer=regularizers.l2(3))(reshape_3)
maxpool_0_3 = MaxPool2D(pool_size=(sequence_length - 3 + 1, 1), strides=(1,1), padding='valid')(conv_0_3)
maxpool_1_3 = MaxPool2D(pool_size=(sequence_length - 4 + 1, 1), strides=(1,1), padding='valid')(conv_1_3)
maxpool_2_3 = MaxPool2D(pool_size=(sequence_length - 5 + 1, 1), strides=(1,1), padding='valid')(conv_2_3)

concatenated_tensor_3 = Concatenate(axis=1)([maxpool_0_3, maxpool_1_3, maxpool_2_3])
flatten_3 = Flatten()(concatenated_tensor_3)

dropout_3 = Dropout(0.5)(flatten_3)
output_3 = Dense(units=3, activation='softmax')(dropout_3)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
ck=ModelCheckpoint("model5.h5",monitor="val_accuracy",save_best_only=True,verbose=1)

# %%
model_3 = Model(inputs=inputs_3, outputs=output_3)
model_3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model_3.summary())
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 55)]         0           []
#
#  embedding_3 (Embedding)        (None, 55, 200)      1233800     ['input_4[0][0]']
#
#  reshape_3 (Reshape)            (None, 55, 200, 1)   0           ['embedding_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 53, 1, 100)   60100       ['reshape_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 52, 1, 100)   80100       ['reshape_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 51, 1, 100)   100100      ['reshape_3[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 1, 1, 100)   0           ['conv2d_9[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 1, 1, 100)   0           ['conv2d_10[0][0]']
#  )
#
#  max_pooling2d_11 (MaxPooling2D  (None, 1, 1, 100)   0           ['conv2d_11[0][0]']
#  )
#
#  concatenate_3 (Concatenate)    (None, 3, 1, 100)    0           ['max_pooling2d_9[0][0]',
#                                                                   'max_pooling2d_10[0][0]',
#                                                                   'max_pooling2d_11[0][0]']
#
#  flatten_3 (Flatten)            (None, 300)          0           ['concatenate_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 300)          0           ['flatten_3[0][0]']
#
#  dense_3 (Dense)                (None, 3)            903         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 1,475,003
# Trainable params: 1,475,003
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
batch_size=50
history_3 = model_3.fit(X, y, epochs=150, batch_size=batch_size, verbose=1, validation_data=(X_test,y_test), shuffle=True, callbacks=[ck])
# Out:
# Epoch 1/150
# 37/37 [==============================] - ETA: 0s - loss: 3.1672 - accuracy: 0.4376
# Epoch 1: val_accuracy improved from -inf to 0.45161, saving model to model5.h5
# 37/37 [==============================] - 11s 251ms/step - loss: 3.1672 - accuracy: 0.4376 - val_loss: 1.3893 - val_accuracy: 0.4516
# Epoch 2/150
# 37/37 [==============================] - ETA: 0s - loss: 1.3020 - accuracy: 0.4321
# Epoch 2: val_accuracy improved from 0.45161 to 0.50230, saving model to model5.h5
# 37/37 [==============================] - 6s 160ms/step - loss: 1.3020 - accuracy: 0.4321 - val_loss: 1.2715 - val_accuracy: 0.5023
# Epoch 3/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2884 - accuracy: 0.4470
# Epoch 3: val_accuracy did not improve from 0.50230
# 37/37 [==============================] - 5s 134ms/step - loss: 1.2884 - accuracy: 0.4470 - val_loss: 1.4306 - val_accuracy: 0.4332
# Epoch 4/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2919 - accuracy: 0.4603
# Epoch 4: val_accuracy did not improve from 0.50230
# 37/37 [==============================] - 5s 128ms/step - loss: 1.2919 - accuracy: 0.4603 - val_loss: 1.3814 - val_accuracy: 0.1843
# Epoch 5/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2962 - accuracy: 0.5083
# Epoch 5: val_accuracy did not improve from 0.50230
# 37/37 [==============================] - 2s 59ms/step - loss: 1.2962 - accuracy: 0.5083 - val_loss: 1.3718 - val_accuracy: 0.3641
# Epoch 6/150
# 37/37 [==============================] - ETA: 0s - loss: 1.3171 - accuracy: 0.5033
# Epoch 6: val_accuracy did not improve from 0.50230
# 37/37 [==============================] - 2s 63ms/step - loss: 1.3171 - accuracy: 0.5033 - val_loss: 1.3303 - val_accuracy: 0.5023
# Epoch 7/150
# 37/37 [==============================] - ETA: 0s - loss: 1.3055 - accuracy: 0.5315
# Epoch 7: val_accuracy did not improve from 0.50230
# 37/37 [==============================] - 1s 38ms/step - loss: 1.3055 - accuracy: 0.5315 - val_loss: 1.4902 - val_accuracy: 0.3779
# Epoch 8/150
# 37/37 [==============================] - ETA: 0s - loss: 1.3101 - accuracy: 0.5646
# Epoch 8: val_accuracy did not improve from 0.50230
# 37/37 [==============================] - 3s 89ms/step - loss: 1.3101 - accuracy: 0.5646 - val_loss: 1.4764 - val_accuracy: 0.3502
# Epoch 9/150
# 37/37 [==============================] - ETA: 0s - loss: 1.3013 - accuracy: 0.5977
# Epoch 9: val_accuracy improved from 0.50230 to 0.64055, saving model to model5.h5
# 37/37 [==============================] - 3s 74ms/step - loss: 1.3013 - accuracy: 0.5977 - val_loss: 1.3343 - val_accuracy: 0.6406
# Epoch 10/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2780 - accuracy: 0.6242
# Epoch 10: val_accuracy did not improve from 0.64055
# 37/37 [==============================] - 1s 26ms/step - loss: 1.2780 - accuracy: 0.6242 - val_loss: 1.5375 - val_accuracy: 0.3318
# Epoch 11/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2584 - accuracy: 0.6490
# Epoch 11: val_accuracy did not improve from 0.64055
# 37/37 [==============================] - 1s 38ms/step - loss: 1.2584 - accuracy: 0.6490 - val_loss: 1.3596 - val_accuracy: 0.5991
# Epoch 12/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2671 - accuracy: 0.6705
# Epoch 12: val_accuracy did not improve from 0.64055
# 37/37 [==============================] - 1s 34ms/step - loss: 1.2671 - accuracy: 0.6705 - val_loss: 1.4521 - val_accuracy: 0.4009
# Epoch 13/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2689 - accuracy: 0.6893
# Epoch 13: val_accuracy did not improve from 0.64055
# 37/37 [==============================] - 1s 26ms/step - loss: 1.2689 - accuracy: 0.6893 - val_loss: 1.3985 - val_accuracy: 0.4931
# Epoch 14/150
# 37/37 [==============================] - ETA: 0s - loss: 1.1966 - accuracy: 0.7401
# Epoch 14: val_accuracy improved from 0.64055 to 0.71429, saving model to model5.h5
# 37/37 [==============================] - 3s 77ms/step - loss: 1.1966 - accuracy: 0.7401 - val_loss: 1.2810 - val_accuracy: 0.7143
# Epoch 15/150
# 37/37 [==============================] - ETA: 0s - loss: 1.2012 - accuracy: 0.7379
# Epoch 15: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 33ms/step - loss: 1.2012 - accuracy: 0.7379 - val_loss: 1.4079 - val_accuracy: 0.5530
# Epoch 16/150
# 34/37 [==========================>...] - ETA: 0s - loss: 1.2078 - accuracy: 0.7688
# Epoch 16: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 2s 45ms/step - loss: 1.1997 - accuracy: 0.7688 - val_loss: 1.3438 - val_accuracy: 0.6866
# Epoch 17/150
# 37/37 [==============================] - ETA: 0s - loss: 1.1840 - accuracy: 0.7792
# Epoch 17: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 2s 42ms/step - loss: 1.1840 - accuracy: 0.7792 - val_loss: 1.4839 - val_accuracy: 0.6037
# Epoch 18/150
# 37/37 [==============================] - ETA: 0s - loss: 1.1287 - accuracy: 0.8118
# Epoch 18: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 2s 58ms/step - loss: 1.1287 - accuracy: 0.8118 - val_loss: 1.3792 - val_accuracy: 0.6267
# Epoch 19/150
# 35/37 [===========================>..] - ETA: 0s - loss: 1.1166 - accuracy: 0.8263
# Epoch 19: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 17ms/step - loss: 1.1178 - accuracy: 0.8267 - val_loss: 1.4165 - val_accuracy: 0.6452
# Epoch 20/150
# 37/37 [==============================] - ETA: 0s - loss: 1.1698 - accuracy: 0.8129
# Epoch 20: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 25ms/step - loss: 1.1698 - accuracy: 0.8129 - val_loss: 1.4177 - val_accuracy: 0.6590
# Epoch 21/150
# 37/37 [==============================] - ETA: 0s - loss: 1.0621 - accuracy: 0.8499
# Epoch 21: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 20ms/step - loss: 1.0621 - accuracy: 0.8499 - val_loss: 1.3887 - val_accuracy: 0.6636
# Epoch 22/150
# 37/37 [==============================] - ETA: 0s - loss: 1.0478 - accuracy: 0.8626
# Epoch 22: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 24ms/step - loss: 1.0478 - accuracy: 0.8626 - val_loss: 1.3949 - val_accuracy: 0.6636
# Epoch 23/150
# 37/37 [==============================] - ETA: 0s - loss: 1.0039 - accuracy: 0.8675
# Epoch 23: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 1.0039 - accuracy: 0.8675 - val_loss: 1.5158 - val_accuracy: 0.5668
# Epoch 24/150
# 37/37 [==============================] - ETA: 0s - loss: 1.0307 - accuracy: 0.8604
# Epoch 24: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 25ms/step - loss: 1.0307 - accuracy: 0.8604 - val_loss: 1.5491 - val_accuracy: 0.6820
# Epoch 25/150
# 37/37 [==============================] - ETA: 0s - loss: 0.9603 - accuracy: 0.8907
# Epoch 25: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.9603 - accuracy: 0.8907 - val_loss: 1.4304 - val_accuracy: 0.6590
# Epoch 26/150
# 37/37 [==============================] - ETA: 0s - loss: 0.9797 - accuracy: 0.8863
# Epoch 26: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.9797 - accuracy: 0.8863 - val_loss: 1.5456 - val_accuracy: 0.6682
# Epoch 27/150
# 37/37 [==============================] - ETA: 0s - loss: 0.9887 - accuracy: 0.8979
# Epoch 27: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 25ms/step - loss: 0.9887 - accuracy: 0.8979 - val_loss: 1.4863 - val_accuracy: 0.6590
# Epoch 28/150
# 32/37 [========================>.....] - ETA: 0s - loss: 0.8862 - accuracy: 0.9069
# Epoch 28: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.8814 - accuracy: 0.9078 - val_loss: 1.4143 - val_accuracy: 0.6682
# Epoch 29/150
# 37/37 [==============================] - ETA: 0s - loss: 0.8529 - accuracy: 0.9134
# Epoch 29: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.8529 - accuracy: 0.9134 - val_loss: 1.4286 - val_accuracy: 0.6866
# Epoch 30/150
# 37/37 [==============================] - ETA: 0s - loss: 0.8722 - accuracy: 0.9211
# Epoch 30: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.8722 - accuracy: 0.9211 - val_loss: 1.4279 - val_accuracy: 0.6544
# Epoch 31/150
# 37/37 [==============================] - ETA: 0s - loss: 0.9878 - accuracy: 0.9134
# Epoch 31: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 12ms/step - loss: 0.9878 - accuracy: 0.9134 - val_loss: 1.7359 - val_accuracy: 0.6912
# Epoch 32/150
# 37/37 [==============================] - ETA: 0s - loss: 0.8253 - accuracy: 0.9189
# Epoch 32: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.8253 - accuracy: 0.9189 - val_loss: 1.5297 - val_accuracy: 0.6498
# Epoch 33/150
# 37/37 [==============================] - ETA: 0s - loss: 0.8271 - accuracy: 0.9294
# Epoch 33: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.8271 - accuracy: 0.9294 - val_loss: 1.6158 - val_accuracy: 0.6498
# Epoch 34/150
# 31/37 [========================>.....] - ETA: 0s - loss: 0.8088 - accuracy: 0.9271
# Epoch 34: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.8038 - accuracy: 0.9244 - val_loss: 2.0623 - val_accuracy: 0.4654
# Epoch 35/150
# 33/37 [=========================>....] - ETA: 0s - loss: 0.9654 - accuracy: 0.9061
# Epoch 35: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.9449 - accuracy: 0.9128 - val_loss: 1.6842 - val_accuracy: 0.6498
# Epoch 36/150
# 31/37 [========================>.....] - ETA: 0s - loss: 0.7663 - accuracy: 0.9374
# Epoch 36: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.7585 - accuracy: 0.9387 - val_loss: 1.4908 - val_accuracy: 0.6590
# Epoch 37/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7319 - accuracy: 0.9404
# Epoch 37: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.7319 - accuracy: 0.9404 - val_loss: 1.9047 - val_accuracy: 0.6313
# Epoch 38/150
# 32/37 [========================>.....] - ETA: 0s - loss: 0.8244 - accuracy: 0.9269
# Epoch 38: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 20ms/step - loss: 0.8116 - accuracy: 0.9294 - val_loss: 1.7737 - val_accuracy: 0.6406
# Epoch 39/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.9476
# Epoch 39: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 30ms/step - loss: 0.7049 - accuracy: 0.9476 - val_loss: 1.7936 - val_accuracy: 0.6590
# Epoch 40/150
# 30/37 [=======================>......] - ETA: 0s - loss: 0.7125 - accuracy: 0.9520
# Epoch 40: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.7017 - accuracy: 0.9520 - val_loss: 1.6196 - val_accuracy: 0.6498
# Epoch 41/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7328 - accuracy: 0.9448
# Epoch 41: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 25ms/step - loss: 0.7328 - accuracy: 0.9448 - val_loss: 1.6970 - val_accuracy: 0.6682
# Epoch 42/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7755 - accuracy: 0.9481
# Epoch 42: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.7755 - accuracy: 0.9481 - val_loss: 1.5980 - val_accuracy: 0.6452
# Epoch 43/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.6965 - accuracy: 0.9482
# Epoch 43: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 11ms/step - loss: 0.7002 - accuracy: 0.9476 - val_loss: 2.0949 - val_accuracy: 0.6267
# Epoch 44/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7066 - accuracy: 0.9547
# Epoch 44: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.7066 - accuracy: 0.9547 - val_loss: 1.6733 - val_accuracy: 0.6682
# Epoch 45/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6600 - accuracy: 0.9597
# Epoch 45: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6600 - accuracy: 0.9597 - val_loss: 1.8962 - val_accuracy: 0.6498
# Epoch 46/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6322 - accuracy: 0.9636
# Epoch 46: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.6322 - accuracy: 0.9636 - val_loss: 1.9207 - val_accuracy: 0.6267
# Epoch 47/150
# 30/37 [=======================>......] - ETA: 0s - loss: 0.6801 - accuracy: 0.9573
# Epoch 47: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 17ms/step - loss: 0.6745 - accuracy: 0.9581 - val_loss: 2.0549 - val_accuracy: 0.6267
# Epoch 48/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6862 - accuracy: 0.9520
# Epoch 48: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6862 - accuracy: 0.9520 - val_loss: 2.0024 - val_accuracy: 0.6452
# Epoch 49/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6872 - accuracy: 0.9614
# Epoch 49: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.6872 - accuracy: 0.9614 - val_loss: 2.2205 - val_accuracy: 0.6359
# Epoch 50/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.6389 - accuracy: 0.9606
# Epoch 50: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6375 - accuracy: 0.9608 - val_loss: 2.0438 - val_accuracy: 0.5576
# Epoch 51/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.5933 - accuracy: 0.9612
# Epoch 51: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5971 - accuracy: 0.9592 - val_loss: 1.8770 - val_accuracy: 0.6590
# Epoch 52/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6103 - accuracy: 0.9603
# Epoch 52: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.6103 - accuracy: 0.9603 - val_loss: 2.3665 - val_accuracy: 0.6221
# Epoch 53/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5502 - accuracy: 0.9749
# Epoch 53: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.5518 - accuracy: 0.9752 - val_loss: 2.5373 - val_accuracy: 0.6267
# Epoch 54/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6472 - accuracy: 0.9619
# Epoch 54: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6472 - accuracy: 0.9619 - val_loss: 2.2629 - val_accuracy: 0.6221
# Epoch 55/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.9570
# Epoch 55: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.6758 - accuracy: 0.9570 - val_loss: 2.6928 - val_accuracy: 0.6083
# Epoch 56/150
# 32/37 [========================>.....] - ETA: 0s - loss: 0.7640 - accuracy: 0.9556
# Epoch 56: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 11ms/step - loss: 0.7548 - accuracy: 0.9542 - val_loss: 3.3781 - val_accuracy: 0.4977
# Epoch 57/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5930 - accuracy: 0.9674
# Epoch 57: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5904 - accuracy: 0.9680 - val_loss: 1.8646 - val_accuracy: 0.6498
# Epoch 58/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5999 - accuracy: 0.9658
# Epoch 58: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.5999 - accuracy: 0.9658 - val_loss: 2.0766 - val_accuracy: 0.6544
# Epoch 59/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5655 - accuracy: 0.9685
# Epoch 59: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 27ms/step - loss: 0.5655 - accuracy: 0.9685 - val_loss: 2.3768 - val_accuracy: 0.6083
# Epoch 60/150
# 33/37 [=========================>....] - ETA: 0s - loss: 0.5936 - accuracy: 0.9703
# Epoch 60: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.5862 - accuracy: 0.9713 - val_loss: 2.0675 - val_accuracy: 0.6452
# Epoch 61/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.9685
# Epoch 61: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.6591 - accuracy: 0.9685 - val_loss: 2.3664 - val_accuracy: 0.6221
# Epoch 62/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6056 - accuracy: 0.9685
# Epoch 62: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.6056 - accuracy: 0.9685 - val_loss: 2.6808 - val_accuracy: 0.6221
# Epoch 63/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5782 - accuracy: 0.9658
# Epoch 63: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.5782 - accuracy: 0.9658 - val_loss: 2.1364 - val_accuracy: 0.6359
# Epoch 64/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5151 - accuracy: 0.9752
# Epoch 64: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 16ms/step - loss: 0.5151 - accuracy: 0.9752 - val_loss: 2.3674 - val_accuracy: 0.6359
# Epoch 65/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.9674
# Epoch 65: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.6888 - accuracy: 0.9674 - val_loss: 2.7736 - val_accuracy: 0.6359
# Epoch 66/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.6463 - accuracy: 0.9689
# Epoch 66: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.6451 - accuracy: 0.9691 - val_loss: 3.3041 - val_accuracy: 0.4562
# Epoch 67/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5129 - accuracy: 0.9713
# Epoch 67: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.5129 - accuracy: 0.9713 - val_loss: 2.7063 - val_accuracy: 0.6267
# Epoch 68/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5771 - accuracy: 0.9713
# Epoch 68: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.5771 - accuracy: 0.9713 - val_loss: 2.6035 - val_accuracy: 0.6221
# Epoch 69/150
# 29/37 [======================>.......] - ETA: 0s - loss: 0.4639 - accuracy: 0.9786
# Epoch 69: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4799 - accuracy: 0.9763 - val_loss: 2.3713 - val_accuracy: 0.6498
# Epoch 70/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7201 - accuracy: 0.9719
# Epoch 70: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.7201 - accuracy: 0.9719 - val_loss: 2.5034 - val_accuracy: 0.6221
# Epoch 71/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5250 - accuracy: 0.9763
# Epoch 71: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.5250 - accuracy: 0.9763 - val_loss: 2.9776 - val_accuracy: 0.5161
# Epoch 72/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.5338 - accuracy: 0.9744
# Epoch 72: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5367 - accuracy: 0.9741 - val_loss: 2.0929 - val_accuracy: 0.5576
# Epoch 73/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7937 - accuracy: 0.9669
# Epoch 73: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.7937 - accuracy: 0.9669 - val_loss: 2.6137 - val_accuracy: 0.6267
# Epoch 74/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5188 - accuracy: 0.9800
# Epoch 74: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5176 - accuracy: 0.9801 - val_loss: 2.0900 - val_accuracy: 0.6313
# Epoch 75/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4579 - accuracy: 0.9812
# Epoch 75: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4579 - accuracy: 0.9812 - val_loss: 2.8746 - val_accuracy: 0.6313
# Epoch 76/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5003 - accuracy: 0.9807
# Epoch 76: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.5003 - accuracy: 0.9807 - val_loss: 2.7660 - val_accuracy: 0.5069
# Epoch 77/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.4984 - accuracy: 0.9739
# Epoch 77: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.4980 - accuracy: 0.9741 - val_loss: 2.8463 - val_accuracy: 0.6359
# Epoch 78/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.9730
# Epoch 78: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5350 - accuracy: 0.9730 - val_loss: 3.1204 - val_accuracy: 0.5622
# Epoch 79/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.4496 - accuracy: 0.9789
# Epoch 79: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4561 - accuracy: 0.9779 - val_loss: 3.4094 - val_accuracy: 0.4516
# Epoch 80/150
# 37/37 [==============================] - ETA: 0s - loss: 0.9281 - accuracy: 0.9669
# Epoch 80: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 14ms/step - loss: 0.9281 - accuracy: 0.9669 - val_loss: 2.6617 - val_accuracy: 0.6359
# Epoch 81/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.5699 - accuracy: 0.9794
# Epoch 81: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5701 - accuracy: 0.9790 - val_loss: 3.5614 - val_accuracy: 0.4977
# Epoch 82/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.4704 - accuracy: 0.9867
# Epoch 82: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4700 - accuracy: 0.9868 - val_loss: 3.6970 - val_accuracy: 0.4747
# Epoch 83/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.5583 - accuracy: 0.9739
# Epoch 83: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5572 - accuracy: 0.9741 - val_loss: 2.4760 - val_accuracy: 0.6359
# Epoch 84/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.9752
# Epoch 84: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4835 - accuracy: 0.9752 - val_loss: 2.8949 - val_accuracy: 0.6359
# Epoch 85/150
# 32/37 [========================>.....] - ETA: 0s - loss: 0.5010 - accuracy: 0.9800
# Epoch 85: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4914 - accuracy: 0.9812 - val_loss: 2.9224 - val_accuracy: 0.6406
# Epoch 86/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5083 - accuracy: 0.9807
# Epoch 86: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5083 - accuracy: 0.9807 - val_loss: 2.2304 - val_accuracy: 0.6313
# Epoch 87/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.9785
# Epoch 87: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4847 - accuracy: 0.9785 - val_loss: 3.1079 - val_accuracy: 0.5023
# Epoch 88/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.4837 - accuracy: 0.9772
# Epoch 88: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 14ms/step - loss: 0.4839 - accuracy: 0.9774 - val_loss: 3.2000 - val_accuracy: 0.6359
# Epoch 89/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.9807
# Epoch 89: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 38ms/step - loss: 0.4709 - accuracy: 0.9807 - val_loss: 2.5587 - val_accuracy: 0.6267
# Epoch 90/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5170 - accuracy: 0.9774
# Epoch 90: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 10ms/step - loss: 0.5170 - accuracy: 0.9774 - val_loss: 3.4018 - val_accuracy: 0.6359
# Epoch 91/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.4576 - accuracy: 0.9818
# Epoch 91: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.4525 - accuracy: 0.9823 - val_loss: 2.6841 - val_accuracy: 0.6313
# Epoch 92/150
# 37/37 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.9829
# Epoch 92: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.3905 - accuracy: 0.9829 - val_loss: 3.6126 - val_accuracy: 0.4977
# Epoch 93/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.9829
# Epoch 93: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.4217 - accuracy: 0.9829 - val_loss: 4.9724 - val_accuracy: 0.4793
# Epoch 94/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.5508 - accuracy: 0.9800
# Epoch 94: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5506 - accuracy: 0.9801 - val_loss: 3.7175 - val_accuracy: 0.5392
# Epoch 95/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4517 - accuracy: 0.9862
# Epoch 95: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4517 - accuracy: 0.9862 - val_loss: 2.7723 - val_accuracy: 0.6175
# Epoch 96/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.3995 - accuracy: 0.9847
# Epoch 96: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.3962 - accuracy: 0.9857 - val_loss: 2.6901 - val_accuracy: 0.6129
# Epoch 97/150
# 37/37 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.9868
# Epoch 97: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.3672 - accuracy: 0.9868 - val_loss: 3.6207 - val_accuracy: 0.6313
# Epoch 98/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.4756 - accuracy: 0.9817
# Epoch 98: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4749 - accuracy: 0.9818 - val_loss: 2.4795 - val_accuracy: 0.6313
# Epoch 99/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.4296 - accuracy: 0.9867
# Epoch 99: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4289 - accuracy: 0.9868 - val_loss: 2.5192 - val_accuracy: 0.6129
# Epoch 100/150
# 37/37 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.9851
# Epoch 100: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.3411 - accuracy: 0.9851 - val_loss: 3.8014 - val_accuracy: 0.5392
# Epoch 101/150
# 37/37 [==============================] - ETA: 0s - loss: 0.6101 - accuracy: 0.9801
# Epoch 101: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.6101 - accuracy: 0.9801 - val_loss: 2.7966 - val_accuracy: 0.6359
# Epoch 102/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5096 - accuracy: 0.9851
# Epoch 102: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.5096 - accuracy: 0.9851 - val_loss: 1.9754 - val_accuracy: 0.6498
# Epoch 103/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.4459 - accuracy: 0.9834
# Epoch 103: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4432 - accuracy: 0.9829 - val_loss: 3.8043 - val_accuracy: 0.4654
# Epoch 104/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4833 - accuracy: 0.9851
# Epoch 104: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4833 - accuracy: 0.9851 - val_loss: 2.6710 - val_accuracy: 0.6313
# Epoch 105/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.9840
# Epoch 105: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 14ms/step - loss: 0.4375 - accuracy: 0.9840 - val_loss: 3.1338 - val_accuracy: 0.5622
# Epoch 106/150
# 30/37 [=======================>......] - ETA: 0s - loss: 0.3921 - accuracy: 0.9840
# Epoch 106: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 19ms/step - loss: 0.3904 - accuracy: 0.9845 - val_loss: 3.6995 - val_accuracy: 0.5023
# Epoch 107/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.5005 - accuracy: 0.9800
# Epoch 107: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5113 - accuracy: 0.9801 - val_loss: 2.9515 - val_accuracy: 0.6359
# Epoch 108/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4841 - accuracy: 0.9868
# Epoch 108: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 16ms/step - loss: 0.4841 - accuracy: 0.9868 - val_loss: 3.1569 - val_accuracy: 0.5207
# Epoch 109/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5590 - accuracy: 0.9785
# Epoch 109: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5590 - accuracy: 0.9785 - val_loss: 3.4472 - val_accuracy: 0.6267
# Epoch 110/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.4395 - accuracy: 0.9878
# Epoch 110: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4393 - accuracy: 0.9879 - val_loss: 2.5538 - val_accuracy: 0.6406
# Epoch 111/150
# 37/37 [==============================] - ETA: 0s - loss: 0.3805 - accuracy: 0.9873
# Epoch 111: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.3805 - accuracy: 0.9873 - val_loss: 3.3987 - val_accuracy: 0.6221
# Epoch 112/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.4759 - accuracy: 0.9829
# Epoch 112: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4783 - accuracy: 0.9834 - val_loss: 4.7519 - val_accuracy: 0.5253
# Epoch 113/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.6214 - accuracy: 0.9778
# Epoch 113: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.6209 - accuracy: 0.9779 - val_loss: 3.0682 - val_accuracy: 0.6221
# Epoch 114/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.9834
# Epoch 114: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5090 - accuracy: 0.9834 - val_loss: 3.0463 - val_accuracy: 0.6313
# Epoch 115/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.4887 - accuracy: 0.9829
# Epoch 115: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4910 - accuracy: 0.9823 - val_loss: 3.5438 - val_accuracy: 0.6221
# Epoch 116/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.5131 - accuracy: 0.9800
# Epoch 116: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5130 - accuracy: 0.9801 - val_loss: 3.6979 - val_accuracy: 0.5576
# Epoch 117/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.3820 - accuracy: 0.9888
# Epoch 117: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.3782 - accuracy: 0.9890 - val_loss: 3.5992 - val_accuracy: 0.5207
# Epoch 118/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4799 - accuracy: 0.9862
# Epoch 118: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4799 - accuracy: 0.9862 - val_loss: 3.2079 - val_accuracy: 0.6267
# Epoch 119/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.4347 - accuracy: 0.9900
# Epoch 119: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4263 - accuracy: 0.9895 - val_loss: 3.1766 - val_accuracy: 0.6221
# Epoch 120/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4018 - accuracy: 0.9901
# Epoch 120: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 17ms/step - loss: 0.4018 - accuracy: 0.9901 - val_loss: 3.8466 - val_accuracy: 0.5991
# Epoch 121/150
# 31/37 [========================>.....] - ETA: 0s - loss: 0.4345 - accuracy: 0.9845
# Epoch 121: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.4310 - accuracy: 0.9857 - val_loss: 4.2051 - val_accuracy: 0.5530
# Epoch 122/150
# 31/37 [========================>.....] - ETA: 0s - loss: 0.3788 - accuracy: 0.9877
# Epoch 122: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.3869 - accuracy: 0.9873 - val_loss: 3.2447 - val_accuracy: 0.6175
# Epoch 123/150
# 30/37 [=======================>......] - ETA: 0s - loss: 0.5147 - accuracy: 0.9860
# Epoch 123: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.5136 - accuracy: 0.9845 - val_loss: 4.1298 - val_accuracy: 0.5346
# Epoch 124/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5369 - accuracy: 0.9868
# Epoch 124: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 18ms/step - loss: 0.5369 - accuracy: 0.9868 - val_loss: 2.5976 - val_accuracy: 0.6406
# Epoch 125/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.7538 - accuracy: 0.9817
# Epoch 125: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.7515 - accuracy: 0.9818 - val_loss: 3.7490 - val_accuracy: 0.4839
# Epoch 126/150
# 30/37 [=======================>......] - ETA: 0s - loss: 0.6052 - accuracy: 0.9807
# Epoch 126: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 10ms/step - loss: 0.5850 - accuracy: 0.9796 - val_loss: 3.5384 - val_accuracy: 0.6359
# Epoch 127/150
# 37/37 [==============================] - ETA: 0s - loss: 0.7215 - accuracy: 0.9845
# Epoch 127: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.7215 - accuracy: 0.9845 - val_loss: 3.6246 - val_accuracy: 0.6313
# Epoch 128/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.7169 - accuracy: 0.9794
# Epoch 128: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.7158 - accuracy: 0.9796 - val_loss: 3.8810 - val_accuracy: 0.6175
# Epoch 129/150
# 30/37 [=======================>......] - ETA: 0s - loss: 0.4219 - accuracy: 0.9920
# Epoch 129: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 9ms/step - loss: 0.4251 - accuracy: 0.9895 - val_loss: 3.8681 - val_accuracy: 0.5576
# Epoch 130/150
# 37/37 [==============================] - ETA: 0s - loss: 0.3529 - accuracy: 0.9906
# Epoch 130: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 14ms/step - loss: 0.3529 - accuracy: 0.9906 - val_loss: 3.5913 - val_accuracy: 0.5115
# Epoch 131/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.3283 - accuracy: 0.9903
# Epoch 131: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.3323 - accuracy: 0.9906 - val_loss: 3.4474 - val_accuracy: 0.6313
# Epoch 132/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4282 - accuracy: 0.9845
# Epoch 132: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4282 - accuracy: 0.9845 - val_loss: 3.2218 - val_accuracy: 0.6313
# Epoch 133/150
# 36/37 [============================>.] - ETA: 0s - loss: 0.5083 - accuracy: 0.9822
# Epoch 133: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5078 - accuracy: 0.9823 - val_loss: 3.5665 - val_accuracy: 0.6406
# Epoch 134/150
# 32/37 [========================>.....] - ETA: 0s - loss: 0.3667 - accuracy: 0.9875
# Epoch 134: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 12ms/step - loss: 0.3655 - accuracy: 0.9879 - val_loss: 3.0254 - val_accuracy: 0.6359
# Epoch 135/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.3920 - accuracy: 0.9851
# Epoch 135: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.3913 - accuracy: 0.9857 - val_loss: 4.9004 - val_accuracy: 0.4747
# Epoch 136/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.4512 - accuracy: 0.9857
# Epoch 136: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4493 - accuracy: 0.9862 - val_loss: 2.7308 - val_accuracy: 0.6498
# Epoch 137/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.3660 - accuracy: 0.9924
# Epoch 137: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.3703 - accuracy: 0.9917 - val_loss: 3.6131 - val_accuracy: 0.6267
# Epoch 138/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.9884
# Epoch 138: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4592 - accuracy: 0.9884 - val_loss: 3.1706 - val_accuracy: 0.6313
# Epoch 139/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5012 - accuracy: 0.9829
# Epoch 139: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5005 - accuracy: 0.9829 - val_loss: 3.4532 - val_accuracy: 0.6313
# Epoch 140/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.3469 - accuracy: 0.9941
# Epoch 140: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.3499 - accuracy: 0.9939 - val_loss: 4.1639 - val_accuracy: 0.5760
# Epoch 141/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5168 - accuracy: 0.9863
# Epoch 141: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.5137 - accuracy: 0.9862 - val_loss: 3.8854 - val_accuracy: 0.6221
# Epoch 142/150
# 33/37 [=========================>....] - ETA: 0s - loss: 0.6123 - accuracy: 0.9848
# Epoch 142: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.5926 - accuracy: 0.9857 - val_loss: 2.9353 - val_accuracy: 0.6406
# Epoch 143/150
# 33/37 [=========================>....] - ETA: 0s - loss: 0.3882 - accuracy: 0.9903
# Epoch 143: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.3901 - accuracy: 0.9895 - val_loss: 4.1723 - val_accuracy: 0.4793
# Epoch 144/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.4045 - accuracy: 0.9874
# Epoch 144: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.4062 - accuracy: 0.9873 - val_loss: 3.2347 - val_accuracy: 0.5853
# Epoch 145/150
# 32/37 [========================>.....] - ETA: 0s - loss: 0.4633 - accuracy: 0.9844
# Epoch 145: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.4552 - accuracy: 0.9857 - val_loss: 3.9288 - val_accuracy: 0.5438
# Epoch 146/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.4000 - accuracy: 0.9880
# Epoch 146: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.3991 - accuracy: 0.9884 - val_loss: 2.9868 - val_accuracy: 0.6406
# Epoch 147/150
# 37/37 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.9879
# Epoch 147: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 13ms/step - loss: 0.4607 - accuracy: 0.9879 - val_loss: 4.8555 - val_accuracy: 0.4516
# Epoch 148/150
# 35/37 [===========================>..] - ETA: 0s - loss: 0.5654 - accuracy: 0.9857
# Epoch 148: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 8ms/step - loss: 0.5644 - accuracy: 0.9862 - val_loss: 4.0685 - val_accuracy: 0.5991
# Epoch 149/150
# 34/37 [==========================>...] - ETA: 0s - loss: 0.4548 - accuracy: 0.9871
# Epoch 149: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 0s 7ms/step - loss: 0.4534 - accuracy: 0.9873 - val_loss: 3.9923 - val_accuracy: 0.6267
# Epoch 150/150
# 37/37 [==============================] - ETA: 0s - loss: 0.5499 - accuracy: 0.9851
# Epoch 150: val_accuracy did not improve from 0.71429
# 37/37 [==============================] - 1s 14ms/step - loss: 0.5499 - accuracy: 0.9851 - val_loss: 3.3985 - val_accuracy: 0.6221

# %%
from keras.saving.saving_api import load_model
model_3=load_model('model5.h5')

# %%
test_seq = tokenizer.texts_to_sequences(dff['SentText'].values)
X_test = pad_sequences(test_seq, maxlen=sequence_length,padding='post')
y_test = pd.get_dummies(dff['Sentiment']).values
y_pred = model_3.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
accuracy_score(list(map(lambda x: np.argmax(x), y_test)), list(map(lambda x: np.argmax(x), y_pred)))*100
# Out:
# 71.42857142857143

# %%
print(classification_report(list(map(lambda x: np.argmax(x), y_test)), list(map(lambda x: np.argmax(x), y_pred))))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77        97
#            1       0.00      0.00      0.00        22
#            2       0.68      0.81      0.74        98
#
#     accuracy                           0.71       217
#    macro avg       0.48      0.53      0.50       217
# weighted avg       0.65      0.71      0.68       217
